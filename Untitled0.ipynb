# %%
import numpy as np

image = np.array([
    [10, 20, 30, 40, 200, 210, 220, 230],
    [15, 25, 35, 45, 195, 205, 215, 225],
    [12, 22, 32, 42, 198, 208, 218, 228],
    [18, 28, 38, 48, 192, 202, 212, 222],
    [14, 24, 34, 44, 196, 206, 216, 226],
    [16, 26, 36, 46, 194, 204, 214, 224],
    [11, 21, 31, 41, 199, 209, 219, 229],
    [13, 23, 33, 43, 197, 207, 217, 227]
])
#result = np.clip(image+30, a_min = None , a_max = 255)
#print(np.mean(image))
#print(image[::-1]) #inverting
#print(image[:,0:4]) #slice 1
#print(image[0:,4:]) #slice 2
#print(np.rot90(image)) #90 degree routing
#print(result)

blocks = []
block_means = []

for r in range(0, 8, 2):
    for c in range(0, 8, 2):
        b = image[r:r+2, c:c+2]
        blocks.append(b)
        block_means.append(np.average(b))
print(np.argmax(block_means))
# Out:
# 15
